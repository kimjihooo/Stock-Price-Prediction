# %% [markdown]
# # 코스피50 주가 예측
# 데이터 출처:
# http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010106

# %% [markdown]
# ## (3) 해석

# %% [markdown]
# ### 변수중요도

# %%
# !pip install shap

# %%
import shap

# %%
# LGBM
explainer = shap.TreeExplainer(final_model) # Tree model Shap Value 확인 객체 지정
shap_values = explainer.shap_values(X_test) # Shap Values 계산

# %%
shap.summary_plot(shap_values, X_test, plot_type = "bar")

# %%
# cat
explainer = shap.TreeExplainer(final_model) # Tree model Shap Value 확인 객체 지정
shap_values = explainer.shap_values(X_test) # Shap Values 계산

# %%
shap.summary_plot(shap_values, X_test, plot_type = "bar")

# %%
# XG
explainer = shap.TreeExplainer(final_model) # Tree model Shap Value 확인 객체 지정
shap_values = explainer.shap_values(X_test) # Shap Values 계산

# %%
shap.summary_plot(shap_values, X_test, plot_type = "bar")

# %%
# rf
explainer = shap.TreeExplainer(final_model) # Tree model Shap Value 확인 객체 지정
shap_values = explainer.shap_values(X_test) # Shap Values 계산

# %%
shap.summary_plot(shap_values, X_test, plot_type = "bar")

# %% [markdown]
# ### 부분의존도

# %%
# !pip install PDPbox

# %% [markdown]
# LGBM

# %%
model = LGBMClassifier(subsample=0.2, n_estimators= 300, min_child_weight= 6, max_depth=7, 
                             learning_rate= 0.06, colsample_bytree=0.7)
model.fit(X_train, y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.7, learning_rate=0.06, max_depth=7,
#                min_child_weight=6, n_estimators=300, subsample=0.2)

# %%
import matplotlib.pyplot as plt
from pdpbox import pdp
feature = 'kospi_close1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f670914e1c0>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6709164be0>})
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
feature = 'BTC/KRW1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6709020eb0>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6709036370>})

# %%
feature = 'close_variation'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6708ae3250>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6708afc640>})

# %% [markdown]
# cat

# %%
model1 = CatBoostClassifier(subsample=0.7, n_estimators= 8000, min_child_samples= 1, max_depth=8, 
                                 learning_rate= 0.07, colsample_bylevel=1)
model1.fit(X_train, y_train)

# %%
feature = 'kospi_close1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model1, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6707aeb310>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6707ae6160>})

# %%
feature = 'BTC/KRW1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model1, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6707268f10>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6707289d60>})

# %%
feature = 'close_variation'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model1, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f67071c6100>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f67071c6940>})

# %% [markdown]
# XG

# %%
model2 = XGBClassifier(subsample=0.8, n_estimators= 300, min_child_weight= 5, max_depth=6, 
                            learning_rate= 0.4, colsample_bytree=0.5)
model2.fit(X_train, y_train)
# Out:
# XGBClassifier(colsample_bytree=0.5, learning_rate=0.4, max_depth=6,
#               min_child_weight=5, n_estimators=300, subsample=0.8)

# %%
feature = 'kospi_close1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model2, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f67071cf400>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f67070f23a0>})

# %%
feature = 'BTC/KRW1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model2, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f670709ca00>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f67070232e0>})

# %%
feature = 'close_variation'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model2, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706f63fa0>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6707024fa0>})

# %% [markdown]
# rf

# %%
model3 = RandomForestClassifier(n_estimators= 300, min_samples_split= 7, max_depth=8, max_features=0.7)
model3.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features=0.7, min_samples_split=7,
#                        n_estimators=300)

# %%
feature = 'kospi_close1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model3, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706ed6310>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706ed3970>})

# %%
feature = 'BTC/KRW1'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model3, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706e578b0>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706dfc580>})

# %%
feature = 'close_variation'
features = X_test.columns
pdp_dist = pdp.pdp_isolate(model=model3, dataset=X_test, model_features=features, feature=feature)
pdp.pdp_plot(pdp_dist, feature)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706d91130>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x7f6706d943a0>})

# %% [markdown]
# ##(4) 앙상블

# %%
base_models = []
base_models.append(('lgb',LGBMClassifier(subsample=0.2, n_estimators= 300, min_child_weight= 6, max_depth=7, 
                             learning_rate= 0.06, colsample_bytree=0.7)))
base_models.append(('cat',CatBoostClassifier(subsample=0.7, n_estimators= 8000, min_child_samples= 1, max_depth=8, 
                                 learning_rate= 0.07, colsample_bylevel=1)))
base_models.append(('xg',XGBClassifier(subsample=0.8, n_estimators= 300, min_child_weight= 5, max_depth=6, 
                            learning_rate= 0.4, colsample_bytree=0.5)))
base_models.append(('rf',RandomForestClassifier(n_estimators= 300, min_samples_split= 7, max_depth=8, max_features=0.7)))

meta_model = LogisticRegression()
clf = StackingClassifier(estimators = base_models, final_estimator = meta_model)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Test score: {:.3f}'.format(accuracy))

# %%
import joblib
joblib.dump(clf, '/content/drive/MyDrive/데이터/주가예측/1216model.pkl')
# Out:
# ['/content/drive/MyDrive/데이터/주가예측/1216model.pkl']

# %%
loaded_model = joblib.load('/content/drive/MyDrive/데이터/주가예측/1216model.pkl')
